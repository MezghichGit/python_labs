# %% [markdown]
# <a href="https://colab.research.google.com/github/MezghichGit/python_labs/blob/master/TP1_Numpy_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1)Initiation à la bibiliothèque Numpy**
#
# lien utile : https://courspython.com/bases-python.html

# %%
import numpy as np
np.pi

a = np.array([1, 2, 3, 4])
print(a)
print(len(a))

b = np.array([[1, 2, 3], [4, 5, 6]])
print(b[1,2])
# Out:
# [1 2 3 4]
# 4
# 6

# %% [markdown]
# **La fonction numpy.arange()**

# %%
m = np.arange(3, 15, 2)
m
# Out:
# array([ 3,  5,  7,  9, 11, 13])

# %% [markdown]
# **La fonction numpy.linspace()**

# %%
np.linspace(0, 1, 10)

x = np.linspace(-np.pi/2, np.pi/2, 3)
y = np.sin(x)
y
# Out:
# array([-1.,  0.,  1.])

# %% [markdown]
# **Comparaison entre around(x,0) et trunc(x)**

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 10)
plt.plot(x, np.around(x,0), label="around(x,0)")
plt.plot(x, np.trunc(x), label="trunc(x)")
print(x)
print(np.around(x,0))
print(np.trunc(x))
plt.legend()

plt.show()
# Out:
# [-2.         -1.55555556 -1.11111111 -0.66666667 -0.22222222  0.22222222
#   0.66666667  1.11111111  1.55555556  2.        ]
# [-2. -2. -1. -1. -0.  0.  1.  1.  2.  2.]
# [-2. -1. -1. -0. -0.  0.  0.  1.  1.  2.]

# %% [markdown]
# # **2)Initiation à Matplotlib**

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot([1, 3, 4, 6], [2, 3, 5, 1])

plt.show() # affiche la figure à l'écran

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 30)
y = np.cos(x)

plt.plot(x, y)

plt.show() # affiche la figure à l'écran

# %% [markdown]
# **Exemple avec axis()**

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 30)
y = np.cos(x)

plt.plot(x, y)
plt.axis([-1, 5, -2, 2])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 30)
y = np.cos(x)

#plt.plot(x, y, label="cos(x)")

y1 = np.cos(x)
y2 = np.sin(x)

#plt.plot(x, y1, label="cos(x)")
#plt.plot(x, y2, label="sin(x)")
plt.plot(x, y1, "r--", label="cos(x)")
plt.plot(x, y2, "b:*", label="sin(x)",linewidth=4)

plt.title("Fonction cosinus")
plt.legend()
plt.xlabel("abscisses")
plt.ylabel("ordonnées")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 40)

x = np.cos(theta)
y = np.sin(theta)

plt.plot(x, y)
plt.axis("equal")
plt.show()
